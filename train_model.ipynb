# %%
# !nvidia-smi

# %%
rom google.colab import drive
drive.mount('/content/drive')

DRIVE_DIR = '/content/drive/MyDrive/dataset_receipt'

# %%
GOATED_TOKEN = ""
REPO_URL = f"https://{GOATED_TOKEN}@github.com/alexisvannson/MethXAI-global.git"
BRANCH = "main"

# !git clone -b {BRANCH} {REPO_URL} /content/MethXAI-global
# %cd /content/MethXAI-global

# %%
# !pip install -q -e .

# %%
import torch
print("torch", torch.__version__, "| cuda:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0), "| bf16:", torch.cuda.is_bf16_supported())
